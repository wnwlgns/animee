# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
import requests
import time
import json
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# 한글 폰트 설정
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False

# %%
# TMDB_API_KEY = '287e229999edb0afe4bf0df40ad08ce7'

BASE_URL = 'https://api.jikan.moe/v4'

# %%
import requests

BASE_URL = "https://api.jikan.moe/v4"

def fetch_top_anime(page=1):
    """Jikan API에서 인기 애니메이션 목록 가져오기"""
    url = f"{BASE_URL}/top/anime"
    params = {
        'page': page
    }

    try:
        response = requests.get(url, params=params, timeout=10)
        response.raise_for_status()
        return response.json().get('data', [])  # 'results'가 아니라 'data'입니다!
    except Exception as e:
        print(f"⚠️ 인기 애니메이션 가져오기 실패: {e}")
        return []


def fetch_anime_details(mal_id):
    """Jikan API에서 개별 애니메이션 상세 정보 가져오기"""
    url = f"{BASE_URL}/anime/{mal_id}"

    try:
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        return response.json().get('data', {})  # ✅ 'data' 키로 접근
    except Exception as e:
        print(f"⚠️ 애니메이션 상세 정보 실패 (ID: {mal_id}): {e}")
        return {}

# %%
def fetch_top_rated_anime(page=1):
    """높은 평점 애니 가져오기"""
    url = f"{BASE_URL}/top/anime"
    params = {
        'filter': 'bypopularity',  # 인기도순 (혹은 'favorite', 'airing' 등으로 변경 가능)
        'page': page
    }

    try:
        response = requests.get(url, params=params, timeout=10)
        response.raise_for_status()
        return response.json().get('data', [])
    except Exception as e:
        print(f"⚠️ 높은 평점 애니 가져오기 실패: {e}")
        return []

def fetch_now_airing_anime(page=1):
    """현재 방영 중인 애니 가져오기"""
    url = f"{BASE_URL}/seasons/now"
    params = {
        'page': page
    }

    try:
        response = requests.get(url, params=params, timeout=10)
        response.raise_for_status()
        return response.json().get('data', [])
    except Exception as e:
        print(f"⚠️ 방영 애니 가져오기 실패: {e}")
        return []

# %%
import time

def collect_anime_by_category(fetch_func, category_name, num_anime=500):
    print(f"📦 {category_name} 애니메이션 수집 중...")

    anime_list = []
    anime_ids = set()
    page = 1

    while len(anime_list) < num_anime:
        result = fetch_func(page)

        if not result:
            print(f"⚠️ 더 이상 데이터 없음 (총 {len(anime_list)}개 수집)")
            break

        for anime in result:
            if anime['mal_id'] not in anime_ids and len(anime_list) < num_anime:
                anime_ids.add(anime['mal_id'])
                anime_list.append(anime)

        print(f"\r진행: {len(anime_list)}/{num_anime}...", end='\r')

        page += 1
        time.sleep(1.5)  # Jikan API rate limit 준수

    print(f"\n✅ {category_name}: 총 {len(anime_list)}개 수집 완료")
    return anime_list

# %%
def collect_anime_data(num_per_category=500):
    print(f"📥 Jikan API에서 애니메이션 데이터 수집 중 (각 카테고리 {num_per_category}개)")
    print("=" * 80)

    all_anime = []
    anime_ids = set()

    # 1. 인기 애니 수집
    popular_anime = collect_anime_by_category(
        fetch_top_rated_anime,
        'Popular',
        num_per_category
    )

    # 2. 높은 평점 애니 수집
    top_rated_anime = collect_anime_by_category(
        fetch_top_rated_anime,
        'Top Rated',
        num_per_category
    )

    # 3. 현재 방영 애니 수집
    now_airing_anime = collect_anime_by_category(
        fetch_now_airing_anime,
        'Now Airing',
        num_per_category
    )

    # 4. 병합 (중복 제거)
    print("\n🔄 데이터 병합 중 (중복 제거)...")
    for anime in popular_anime + top_rated_anime + now_airing_anime:
        if anime['mal_id'] not in anime_ids:
            anime_ids.add(anime['mal_id'])
            all_anime.append(anime)

    print(f"  ✓ 총 수집: {len(popular_anime) + len(top_rated_anime) + len(now_airing_anime)}개")
    print(f"  ✓ 중복 제거 후: {len(all_anime)}개")

    print("\n" + "=" * 80)
    print(f"✅ 기본 정보 수집 완료: {len(all_anime)}개")

    # 상세 정보 수집
    print("\n📝 애니메이션 상세 정보 수집 중...")
    print("  (시간이 걸릴 수 있습니다...)")
    detailed_anime = []

    total = len(all_anime)
    for i, anime in enumerate(all_anime, 1):
        if i % 50 == 0 or i == total:
            print(f"  진행: {i}/{total} ({i/total*100:.1f}%)...")

        details = fetch_anime_details(anime['mal_id'])  # <- 여기가 핵심
        if details:
            detailed_anime.append(details)

        time.sleep(0.5)  # Jikan API 요청 제한

    print(f"\n✅ 상세 정보 수집 완료: {len(detailed_anime)}개")

    # 카테고리별 통계
    print("\n📊 카테고리별 통계:")
    print(f"  - Popular: {len(popular_anime)}개")
    print(f"  - Top Rated: {len(top_rated_anime)}개")
    print(f"  - Now Airing: {len(now_airing_anime)}개")
    print(f"  - 최종 (중복 제거): {len(detailed_anime)}개")

    return detailed_anime

# %%
def parse_anime_data(anime_data_list):
    """
    Jikan API 응답 데이터를 DataFrame으로 변환
    """
    print("\n🔧 애니메이션 데이터 파싱 중...")

    parsed_anime = []

    for anime in anime_data_list:
        genres = '|'.join([g['name'] for g in anime.get('genres', [])])
        studios = '|'.join([s['name'] for s in anime.get('studios', [])])
        themes = '|'.join([t['name'] for t in anime.get('themes', [])])
        demographics = '|'.join([d['name'] for d in anime.get('demographics', [])])

        parsed = {
            'mal_id': anime['mal_id'],
            'title': anime.get('title', ''),
            'title_english': anime.get('title_english', ''),
            'synopsis': anime.get('synopsis', ''),
            'genres': genres,
            'themes': themes,
            'score': anime.get('score', 0),
            'scored_by': anime.get('scored_by', 0),
            'popularity': anime.get('popularity', 0),
            'rank': anime.get('rank', 0),
            'season': anime.get('season', ''),
            'year': anime.get('year', ''),
          }

        parsed_anime.append(parsed)

    df = pd.DataFrame(parsed_anime)
    print(f"  ✓ 파싱 완료: {len(df)}개 애니메이션")
    return df

# %%
print("데이터 수집 시작...")
print()

# 1. 애니메이션 데이터 수집 (Top, Now, 등 다양한 카테고리 기반)
anime_raw = collect_anime_data(num_per_category=100)

# 2. 상세 정보를 포함한 데이터를 파싱하여 DataFrame으로 변환
df = parse_anime_data(anime_raw)

# 3. 요약 통계 출력
print("\n" + "=" * 80)
print("📊 수집된 애니메이션 데이터 정보")
print("=" * 80)
print(f"총 애니 수: {len(df)}")
print(f"평균 인기도: {df['popularity'].mean():.1f}")
print(f"\n상위 5개 애니:")
print(df[['title', 'season', 'year']].head())
# Out:
# 데이터 수집 시작...
#
# 📥 Jikan API에서 애니메이션 데이터 수집 중 (각 카테고리 100개)
# ================================================================================
# 📦 Popular 애니메이션 수집 중...
# 진행: 100/100...
# ✅ Popular: 총 100개 수집 완료
# 📦 Top Rated 애니메이션 수집 중...
# 진행: 100/100...
# ✅ Top Rated: 총 100개 수집 완료
# 📦 Now Airing 애니메이션 수집 중...
# 진행: 100/100...
# ✅ Now Airing: 총 100개 수집 완료
#
# 🔄 데이터 병합 중 (중복 제거)...
#   ✓ 총 수집: 300개
#   ✓ 중복 제거 후: 200개
#
# ================================================================================
# ✅ 기본 정보 수집 완료: 200개
#
# 📝 애니메이션 상세 정보 수집 중...
#   (시간이 걸릴 수 있습니다...)
#   진행: 50/200 (25.0%)...
#   진행: 100/200 (50.0%)...
#   진행: 150/200 (75.0%)...
#   진행: 200/200 (100.0%)...
#
# ✅ 상세 정보 수집 완료: 200개
#
# 📊 카테고리별 통계:
#   - Popular: 100개
#   - Top Rated: 100개
#   - Now Airing: 100개
#   - 최종 (중복 제거): 200개
#
# 🔧 애니메이션 데이터 파싱 중...
#   ✓ 파싱 완료: 200개 애니메이션
#
# ================================================================================
# 📊 수집된 애니메이션 데이터 정보
# ================================================================================
# 총 애니 수: 200
# 평균 인기도: 4239.5
#
# 상위 5개 애니:
#                               title  season    year
# 0                Shingeki no Kyojin  spring  2013.0
# 1                        Death Note    fall  2006.0
# 2  Fullmetal Alchemist: Brotherhood  spring  2009.0
# 3                     One Punch Man    fall  2015.0
# 4                  Kimetsu no Yaiba  spring  2019.0

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# =============================
# 1. 결측치 처리 및 텍스트 클린
# =============================

df['synopsis'] = df['synopsis'].fillna('')
df['genres'] = df['genres'].fillna('')
df['themes'] = df['themes'].fillna('')


# 텍스트 정제 함수
def clean_text(text):
    if pd.isna(text):
        return ''
    text = str(text).lower()
    text = text.replace('|', ' ')
    return text

# soup 컬럼 생성 (텍스트 통합)
df['soup'] = (
    df['synopsis'] + ' ' +
    df['genres'] + ' ' +
    df['themes']
)

df['soup'] = df['soup'].apply(clean_text)

print("✅ 애니메이션 텍스트 통합 및 정제 완료")

# =============================
# 2. TF-IDF 벡터화 및 유사도 계산
# =============================

print("\n🔢 TF-IDF 벡터화 중...")

tfidf = TfidfVectorizer(
    max_features=5000,
    stop_words='english',
    ngram_range=(1, 2),
    min_df=2,
)

tfidf_matrix = tfidf.fit_transform(df['soup'])
print(f"✓ TF-IDF 행렬 크기: {tfidf_matrix.shape}")

print("\n🔍 코사인 유사도 계산 중...")
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)
print(f"✓ 유사도 행렬 크기: {cosine_sim.shape}")

# =============================
# 3. 인덱스 매핑
# =============================

indices = pd.Series(df.index, index=df['title']).drop_duplicates()

# =============================
# 4. 추천 함수
# =============================

def get_recommendations(title, cosine_sim=cosine_sim, df=df, top_n=10):
    """애니메이션 추천 함수"""
    try:
        idx = indices[title]
        sim_scores = list(enumerate(cosine_sim[idx]))
        sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
        sim_scores = sim_scores[1:top_n+1]

        anime_indices = [i[0] for i in sim_scores]

        recommendations = df.iloc[anime_indices][['title', 'genres', 'score', 'popularity']].copy()
        recommendations['similarity_score'] = [score[1] for score in sim_scores]

        return recommendations

    except KeyError:
        print(f"\n❌ '{title}' 애니메이션을 찾을 수 없습니다.")
        print(f"\n사용 가능한 애니 제목 예시:")
        for i, anime in enumerate(df['title'].head(10), 1):
            print(f"  {i}. {anime}")
        return None

# =============================
# 5. 검색 함수
# =============================

def search_anime(keyword, df=df, top_n=10):
    """애니 제목 검색"""
    results = df[df['title'].str.contains(keyword, case=False, na=False)]
    if len(results) == 0:
        print(f"\n'{keyword}'로 검색된 애니가 없습니다.")
        return None
    return results[['title', 'genres', 'score']].head(top_n)


# =============================
# 6. 사용 예시
# =============================

# 🔍 제목 검색
# search_anime("Naruto")

# 🎯 추천 받기
get_recommendations("One Punch Man")
# Out:
# ✅ 애니메이션 텍스트 통합 및 정제 완료
#
# 🔢 TF-IDF 벡터화 중...
# ✓ TF-IDF 행렬 크기: (200, 2154)
#
# 🔍 코사인 유사도 계산 중...
# ✓ 유사도 행렬 크기: (200, 200)
#                                                  title  \
# 54                            One Punch Man 2nd Season
# 100                                    One Punch Man 3
# 163  One Punch Man 2nd Season: Ichigeki de Wakaru! ...
# 128       Toujima Tanzaburou wa Kamen Rider ni Naritai
# 6                                Boku no Hero Academia
# 187            Osomatsu-san 4th Season: Sou, Shuu, Hen
# 102                Boku no Hero Academia: Final Season
# 141                          Undead Unluck: Winter-hen
# 112                   Yasei no Last Boss ga Arawareta!
# 42                          Kiseijuu: Sei no Kakuritsu
#
#                             genres  score  popularity  similarity_score
# 54                   Action|Comedy   7.54          55          0.378078
# 100                  Action|Comedy   6.14         704          0.210109
# 163                  Action|Comedy   6.33        9694          0.198854
# 128                  Action|Comedy   7.70        4624          0.132242
# 6                           Action   7.83           7          0.099331
# 187                         Comedy    NaN       16409          0.086625
# 102                         Action   8.80        1549          0.084754
# 141          Action|Comedy|Fantasy    NaN        5347          0.082209
# 112       Action|Adventure|Fantasy   7.43        3475          0.078708
# 42   Action|Horror|Sci-Fi|Suspense   8.32          43          0.078463

# %%
print("\n" + "=" * 80)
print("🎯 대화형 애니메이션 추천 시스템")
print("=" * 80)

def interactive_recommendation():
    """대화형 애니 추천 시스템"""
    print("\n사용 가능한 애니 목록 (랜덤 20개):")

    # 랜덤하게 20개 선택
    sample_size = min(20, len(df))
    random_animes = df.sample(sample_size)['title'].tolist()

    for i, anime in enumerate(random_animes, 1):
        print(f"  {i}. {anime}")

    print("\n" + "-" * 80)
    print("명령어:")
    print("  - 애니 제목 입력: 해당 애니와 유사한 애니 추천")
    print("  - 'search [키워드]': 애니 제목 검색")
    print("  - 'list': 전체 애니 목록 보기")
    print("  - 'random': 랜덤 20개 다시 보기")
    print("  - 'quit': 종료")
    print("-" * 80)

    while True:
        user_input = input("\n🎬 애니 제목을 입력하세요: ").strip()

        if user_input.lower() == 'quit':
            print("\n👋 추천 시스템을 종료합니다!")
            break

        elif user_input.lower() == 'random':
            print("\n🎲 랜덤 애니 20개:")
            sample_size = min(20, len(df))
            random_animes = df.sample(sample_size)['title'].tolist()
            for i, anime in enumerate(random_animes, 1):
                print(f"  {i}. {anime}")

        elif user_input.lower() == 'list':
            print(f"\n전체 애니 목록 ({len(df)}편):")
            for i, anime in enumerate(df['title'], 1):
                print(f"  {i}. {anime}")

        elif user_input.lower().startswith('search '):
            keyword = user_input[7:]
            results = search_anime(keyword)
            if results is not None:
                print(f"\n🔍 '{keyword}' 검색 결과:")
                print(results.to_string(index=False))

        elif user_input in df['title'].values:
            recommendations = get_recommendations(user_input, top_n=5)
            if recommendations is not None:
                print(f"\n✨ '{user_input}'와 유사한 애니 추천:")
                print("\n" + recommendations.to_string(index=False))

        else:
            print(f"\n❌ '{user_input}' 애니를 찾을 수 없습니다.")
            print("'list' 명령으로 전체 목록을 확인하거나, 'search [키워드]'로 검색하세요.")

# 실행
interactive_recommendation()
# Out:
# ================================================================================
# 🎯 대화형 애니메이션 추천 시스템
# ================================================================================
#
# 사용 가능한 애니 목록 (랜덤 20개):
#   1. Do S na Pet
#   2. Another
#   3. Yonghansonyeo
#   4. Bakemonogatari
#   5. Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka
#   6. Enen no Shouboutai
#   7. Kikaijikake no Marie
#   8. Kiseijuu: Sei no Kakuritsu
#   9. Shingeki no Kyojin Season 3
#   10. Chitose-kun wa Ramune Bin no Naka
#   11. Kimetsu no Yaiba: Yuukaku-hen
#   12. Bukiyou na Senpai.
#   13. Darling in the FranXX
#   14. Yasei no Last Boss ga Arawareta!
#   15. Chichi wa Eiyuu, Haha wa Seirei, Musume no Watashi wa Tenseisha.
#   16. Jujutsu Kaisen
#   17. Death Note
#   18. Boku no Hero Academia 3rd Season
#   19. Sanda
#   20. Xian Wang de Richang Shenghuo 5
#
# --------------------------------------------------------------------------------
# 명령어:
#   - 애니 제목 입력: 해당 애니와 유사한 애니 추천
#   - 'search [키워드]': 애니 제목 검색
#   - 'list': 전체 애니 목록 보기
#   - 'random': 랜덤 20개 다시 보기
#   - 'quit': 종료
# --------------------------------------------------------------------------------
#
# ✨ 'Sanda'와 유사한 애니 추천:
#
#                                    title                  genres  score  popularity  similarity_score
#                          Yeon-ui Pyeonji Adventure|Drama|Mystery    NaN       12312          0.152908
#                      Hateshinaki Scarlet                 Fantasy    NaN        7720          0.152248
#                                Toradora!           Drama|Romance   8.04          26          0.124256
#                                  Shabake    Mystery|Supernatural   6.32        6782          0.114532
# Chou Futsuu Mahou Shoujo Asumi Toruverse                  Comedy    NaN       13969          0.112338
#
# ✨ 'Boku no Hero Academia 3rd Season'와 유사한 애니 추천:
#
#                               title        genres  score  popularity  similarity_score
# Boku no Hero Academia: Final Season        Action   8.80        1549          0.300564
#    Boku no Hero Academia 4th Season        Action   7.86          53          0.292348
#               Boku no Hero Academia        Action   7.83           7          0.257404
#    Boku no Hero Academia 2nd Season        Action   8.05          16          0.250327
#                  Ansatsu Kyoushitsu Action|Comedy   8.07          34          0.143092
#
# 전체 애니 목록 (200편):
#   1. Shingeki no Kyojin
#   2. Death Note
#   3. Fullmetal Alchemist: Brotherhood
#   4. One Punch Man
#   5. Kimetsu no Yaiba
#   6. Sword Art Online
#   7. Boku no Hero Academia
#   8. Hunter x Hunter (2011)
#   9. Naruto
#   10. Tokyo Ghoul
#   11. Kimi no Na wa.
#   12. Shingeki no Kyojin Season 2
#   13. Jujutsu Kaisen
#   14. Steins;Gate
#   15. Naruto: Shippuuden
#   16. Boku no Hero Academia 2nd Season
#   17. One Piece
#   18. Shingeki no Kyojin Season 3
#   19. Koe no Katachi
#   20. No Game No Life
#   21. Shingeki no Kyojin Season 3 Part 2
#   22. Code Geass: Hangyaku no Lelouch
#   23. Re:Zero kara Hajimeru Isekai Seikatsu
#   24. Shigatsu wa Kimi no Uso
#   25. Boku no Hero Academia 3rd Season
#   26. Toradora!
#   27. Noragami
#   28. Mob Psycho 100
#   29. Boku dake ga Inai Machi
#   30. Akame ga Kill!
#   31. Shingeki no Kyojin: The Final Season
#   32. Nanatsu no Taizai
#   33. Angel Beats!
#   34. Ansatsu Kyoushitsu
#   35. Bleach
#   36. Haikyuu!!
#   37. Yakusoku no Neverland
#   38. Mirai Nikki (TV)
#   39. Kono Subarashii Sekai ni Shukufuku wo!
#   40. Sword Art Online II
#   41. Ao no Exorcist
#   42. Cowboy Bebop
#   43. Kiseijuu: Sei no Kakuritsu
#   44. Sen to Chihiro no Kamikakushi
#   45. Shinseiki Evangelion
#   46. Violet Evergarden
#   47. Code Geass: Hangyaku no Lelouch R2
#   48. Seishun Buta Yarou wa Bunny Girl Senpai no Yume wo Minai
#   49. Dr. Stone
#   50. Kaguya-sama wa Kokurasetai: Tensai-tachi no Renai Zunousen
#   51. Death Parade
#   52. Tokyo Ghoul √A
#   53. Boku no Hero Academia 4th Season
#   54. Black Clover
#   55. One Punch Man 2nd Season
#   56. Chainsaw Man
#   57. Fairy Tail
#   58. Kill la Kill
#   59. Spy x Family
#   60. JoJo no Kimyou na Bouken (TV)
#   61. Darling in the FranXX
#   62. Another
#   63. Vinland Saga
#   64. Soul Eater
#   65. Charlotte
#   66. Tate no Yuusha no Nariagari
#   67. Tengen Toppa Gurren Lagann
#   68. Shokugeki no Souma
#   69. Psycho-Pass
#   70. Kimetsu no Yaiba Movie: Mugen Ressha-hen
#   71. Overlord
#   72. Ano Hi Mita Hana no Namae wo Bokutachi wa Mada Shiranai.
#   73. Mob Psycho 100 II
#   74. Kimetsu no Yaiba: Yuukaku-hen
#   75. Hataraku Maou-sama!
#   76. Dungeon ni Deai wo Motomeru no wa Machigatteiru Darou ka
#   77. Kono Subarashii Sekai ni Shukufuku wo! 2
#   78. Tensei shitara Slime Datta Ken
#   79. Kakegurui
#   80. Elfen Lied
#   81. Highschool of the Dead
#   82. Fate/Zero
#   83. Horimiya
#   84. Fullmetal Alchemist
#   85. Noragami Aragoto
#   86. Ansatsu Kyoushitsu 2nd Season
#   87. Haikyuu!! Second Season
#   88. Yahari Ore no Seishun Love Comedy wa Machigatteiru.
#   89. Bungou Stray Dogs
#   90. Mushoku Tensei: Isekai Ittara Honki Dasu
#   91. Made in Abyss
#   92. High School DxD
#   93. Enen no Shouboutai
#   94. Shingeki no Kyojin: The Final Season Part 2
#   95. Clannad
#   96. Durarara!!
#   97. Bakemonogatari
#   98. Kaguya-sama wa Kokurasetai? Tensai-tachi no Renai Zunousen
#   99. Hyouka
#   100. Howl no Ugoku Shiro
#   101. One Punch Man 3
#   102. Spy x Family Season 3
#   103. Boku no Hero Academia: Final Season
#   104. Fumetsu no Anata e Season 3
#   105. Saigo ni Hitotsu dake Onegai shitemo Yoroshii deshou ka
#   106. Ansatsusha de Aru Ore no Status ga Yuusha yori mo Akiraka ni Tsuyoi no da ga
#   107. Tomodachi no Imouto ga Ore ni dake Uzai
#   108. Tondemo Skill de Isekai Hourou Meshi 2
#   109. Sanda
#   110. Ranma ½ (2024) 2nd Season
#   111. Towa no Yuugure
#   112. Watashi wo Tabetai, Hitodenashi
#   113. Yasei no Last Boss ga Arawareta!
#   114. Shinjiteita Nakama-tachi ni Dungeon Okuchi de Korosarekaketa ga Gift "Mugen Gacha" de Level 9999 no Nakama-tachi wo Te ni Irete Moto Party Member to Sekai ni Fukushuu & "Zamaa!" Shimasu!
#   115. Nageki no Bourei wa Intai shitai Part 2
#   116. Mushoku no Eiyuu: Betsu ni Skill Nanka Iranakatta n da ga
#   117. Bukiyou na Senpai.
#   118. Chitose-kun wa Ramune Bin no Naka
#   119. Akujiki Reijou to Kyouketsu Koushaku
#   120. 3-nen Z-gumi Ginpachi-sensei
#   121. Mikata ga Yowasugite Hojo Mahou ni Tesshiteita Kyuutei Mahoushi, Tsuihou sarete Saikyou wo Mezasu
#   122. Sozai Saishuka no Isekai Ryokouki
#   123. Yano-kun no Futsuu no Hibi
#   124. Zombieland Saga Movie: Yumeginga Paradise
#   125. Chichi wa Eiyuu, Haha wa Seirei, Musume no Watashi wa Tenseisha.
#   126. Kekkon Yubiwa Monogatari II
#   127. Isekai Quartet 3
#   128. Kao ni Denai Kashiwada-san to Kao ni Deru Oota-kun
#   129. Toujima Tanzaburou wa Kamen Rider ni Naritai
#   130. Uma Musume: Cinderella Gray Part 2
#   131. Kikaijikake no Marie
#   132. Wandance
#   133. Taiyou yori mo Mabushii Hoshi
#   134. Sawaranaide Kotesashi-kun
#   135. Tensei Akujo no Kuro Rekishi
#   136. Kakuriyo no Yadomeshi Ni
#   137. Chanto Suenai Kyuuketsuki-chan
#   138. Disney Twisted-Wonderland The Animation: Episode of Heartslabyul
#   139. Gnosia
#   140. Kingdom 6th Season
#   141. Kimi to Koete Koi ni Naru
#   142. Undead Unluck: Winter-hen
#   143. Shuumatsu no Walküre III
#   144. Let's Play: Quest-darake no My Life
#   145. Digimon Beatbreak
#   146. Alma-chan wa Kazoku ni Naritai
#   147. Shuumatsu Touring
#   148. Egao no Taenai Shokuba desu.
#   149. Ao no Orchestra Season 2
#   150. Xian Wang de Richang Shenghuo 5
#   151. Fujimoto Tatsuki 17-26
#   152. Shabake
#   153. Golden Kamuy: Sapporo Beer Koujou-hen
#   154. Debu to Love to Ayamachi to!
#   155. Ninja to Gokudou
#   156. Potion, Wagami wo Tasukeru
#   157. Star Wars: Visions Volume 3
#   158. Golden Kamuy: Inazuma Goutou to Mamushi no Ogin/Shimaenaga
#   159. Hateshinaki Scarlet
#   160. Girls Band Cry Movie
#   161. Heika Watashi wo Wasurete Kudasai
#   162. SI-VIS: The Sound of Heroes
#   163. Ganglion
#   164. One Punch Man 2nd Season: Ichigeki de Wakaru! Maji Furikaeri!
#   165. Love Live! Nijigasaki Gakuen School Idol Doukoukai: Kanketsu-hen Part 2
#   166. Housenka
#   167. Kono Hon wo Nusumu Mono wa
#   168. Monster Strike: Deadverse Reloaded
#   169. Nohara Hiroshi: Hiru Meshi no Ryuugi
#   170. Kidou Senshi Gundam: Tekketsu no Orphans - Makuai no Kusabi
#   171. Peleliu: Rakuen no Guernica
#   172. Ganso! Bandori-chan
#   173. Yeon-ui Pyeonji
#   174. Guilty Hole
#   175. Girls & Panzer: Motto Love Love Sakusen desu!
#   176. Wei Miao Rensheng
#   177. IDOLiSH7: First Beat
#   178. 2200-nen Neko no Kuni Nippon
#   179. Hyakushou Kizoku 3rd Season
#   180. Chou Futsuu Mahou Shoujo Asumi Toruverse
#   181. Aikatsu! x PriPara the Movie: Deai no Kiseki!
#   182. Kidou Senshi Gundam: Tekketsu no Orphans - Urdr Hunt: Chiisana Chousensha no Kiseki
#   183. One Piece: Dr. Chopper no Bouken Karte - Uragirimono-tachi no Masquerade
#   184. Shi Wai (2025)
#   185. Gu Xiong
#   186. Toritsukare Otoko
#   187. Reika wa Karei na Boku no Joou The Animation
#   188. Osomatsu-san 4th Season: Sou, Shuu, Hen
#   189. Choro Mesu Days
#   190. Yonghansonyeo
#   191. Poketoon (2025)
#   192. H na Ane Series The Animation
#   193. Natsuzuma
#   194. Nagachichi Nagai-san The Animation
#   195. Mafiosa
#   196. Seikon no Aria
#   197. Natsu to Hako
#   198. Do S na Pet
#   199. Koala Enikki
#   200. Wadachi wo Koete Yuke
#
# 👋 추천 시스템을 종료합니다!
